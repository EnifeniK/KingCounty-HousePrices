# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('TensorFlow_FILES/DATA/kc_house_data.csv')

# %%
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='price', data=df)
# Out:
# <Axes: xlabel='price', ylabel='count'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='price', y='price', data=df)
# Out:
# <Axes: xlabel='price', ylabel='price'>

# %%
df.sort_values('price', ascending=False).head(30)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
dff = pd.DataFrame(df.sort_values('price', ascending=False).iloc[13:])

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21584 entries, 7028 to 15279
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21584 non-null  int64
#  1   date           21584 non-null  object
#  2   price          21584 non-null  float64
#  3   bedrooms       21584 non-null  int64
#  4   bathrooms      21584 non-null  float64
#  5   sqft_living    21584 non-null  int64
#  6   sqft_lot       21584 non-null  int64
#  7   floors         21584 non-null  float64
#  8   waterfront     21584 non-null  int64
#  9   view           21584 non-null  int64
#  10  condition      21584 non-null  int64
#  11  grade          21584 non-null  int64
#  12  sqft_above     21584 non-null  int64
#  13  sqft_basement  21584 non-null  int64
#  14  yr_built       21584 non-null  int64
#  15  yr_renovated   21584 non-null  int64
#  16  zipcode        21584 non-null  int64
# ...

# %%
dff.head(5)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7028    853200010   7/1/2014  3800000.0         5       5.50         7050
# 19002  2303900100  9/11/2014  3800000.0         3       4.25         5510
# 16288  7397300170  5/30/2014  3710000.0         4       3.50         5550
# 18467  4389201095  5/11/2015  3650000.0         5       3.75         5020
# 6502   4217402115  4/21/2015  3650000.0         6       4.75         5480
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7028      42840     1.0           0     2  ...     13        4320
# 19002     35000     2.0           0     4  ...     13        4910
# 16288     28078     2.0           0     2  ...     12        3350
# 18467      8694     2.0           0     1  ...     12        3970
# 6502      19401     1.5           1     4  ...     11        3910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Feature Engineering

# %%
dff = dff.drop('id', axis=1)

# %%
dff
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7028    7/1/2014  3800000.0         5       5.50         7050     42840
# 19002  9/11/2014  3800000.0         3       4.25         5510     35000
# 16288  5/30/2014  3710000.0         4       3.50         5550     28078
# 18467  5/11/2015  3650000.0         5       3.75         5020      8694
# 6502   4/21/2015  3650000.0         6       4.75         5480     19401
# ...          ...        ...       ...        ...          ...       ...
# 2139    5/8/2014    82500.0         2       1.00          520     22334
# 8267   11/5/2014    82000.0         3       1.00          860     10426
# 16184  3/24/2015    81000.0         2       1.00          730      9975
# 465    5/23/2014    80000.0         1       0.75          430      5050
# 15279   5/6/2014    78000.0         2       1.00          780     16344
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dff['date'] = pd.to_datetime(dff['date'])

# %%
dff['month'] = dff['date'].apply(lambda date: date.month)
dff['year'] = dff['date'].apply(lambda date: date.year)

# %%
dff = dff.drop('date', axis=1)

# %%
dff.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7028   3800000.0         5       5.50         7050     42840     1.0
# 19002  3800000.0         3       4.25         5510     35000     2.0
# 16288  3710000.0         4       3.50         5550     28078     2.0
# 18467  3650000.0         5       3.75         5020      8694     2.0
# 6502   3650000.0         6       4.75         5480     19401     1.5
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 7028            0     2          4     13  ...           2730      1978
# 19002           0     4          3     13  ...            600      1997
# 16288           0     2          4     12  ...           2200      2000
# 18467           0     1          3     12  ...           1050      2007
# 6502            1     4          5     11  ...           1570      1936
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
dff = dff.drop('zipcode', axis=1)

# %%
dff.head(5)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7028   3800000.0         5       5.50         7050     42840     1.0
# 19002  3800000.0         3       4.25         5510     35000     2.0
# 16288  3710000.0         4       3.50         5550     28078     2.0
# 18467  3650000.0         5       3.75         5020      8694     2.0
# 6502   3650000.0         6       4.75         5480     19401     1.5
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 7028            0     2          4     13        4320           2730
# 19002           0     4          3     13        4910            600
# 16288           0     2          4     12        3350           2200
# 18467           0     1          3     12        3970           1050
# 6502            1     4          5     11        3910           1570
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
dff['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0       13108
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 2300        1
# 1548        1
# 2190        1
# 2720        1
# 2730        1
# Name: count, Length: 301, dtype: int64

# %%
dfy = dff

# %%
basement = pd.get_dummies(dff['sqft_basement'])

# %%
def class_basement(col):
        if col == 0:
            return 0
        else:
            return 1

# %%
dff['sqft_basement'] = dff['sqft_basement'].apply(class_basement)

# %%
dff.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7028   3800000.0         5       5.50         7050     42840     1.0
# 19002  3800000.0         3       4.25         5510     35000     2.0
# 16288  3710000.0         4       3.50         5550     28078     2.0
# 18467  3650000.0         5       3.75         5020      8694     2.0
# 6502   3650000.0         6       4.75         5480     19401     1.5
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 7028            0     2          4     13        4320              1
# 19002           0     4          3     13        4910              1
# 16288           0     2          4     12        3350              1
# 18467           0     1          3     12        3970              1
# 6502            1     4          5     11        3910              1
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
dff['basement'] = dff['sqft_basement']

# %%
dff = dff.drop('sqft_basement', axis=1)

# %%
dff.head(5)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7028   3800000.0         5       5.50         7050     42840     1.0
# 19002  3800000.0         3       4.25         5510     35000     2.0
# 16288  3710000.0         4       3.50         5550     28078     2.0
# 18467  3650000.0         5       3.75         5020      8694     2.0
# 6502   3650000.0         6       4.75         5480     19401     1.5
#
#        waterfront  view  condition  grade  sqft_above  yr_built  yr_renovated  \
# 7028            0     2          4     13        4320      1978             0
# 19002           0     4          3     13        4910      1997             0
# 16288           0     2          4     12        3350      2000             0
# 18467           0     1          3     12        3970      2007             0
# 6502            1     4          5     11        3910      1936             0
#
#            lat     long  sqft_living15  sqft_lot15  month  year  basement
# ...

# %%
dff['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20673
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1948        1
# 1959        1
# 1951        1
# 1954        1
# Name: count, Length: 70, dtype: int64

# %%
def reno(col):
    if col <= 2000:
        return 0
    else:
        return 1

# %%
dff['renovated'] = dff['yr_renovated'].apply(reno)

# %%
dff = dff.drop('yr_renovated', axis=1)

# %%
dff
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7028   3800000.0         5       5.50         7050     42840     1.0
# 19002  3800000.0         3       4.25         5510     35000     2.0
# 16288  3710000.0         4       3.50         5550     28078     2.0
# 18467  3650000.0         5       3.75         5020      8694     2.0
# 6502   3650000.0         6       4.75         5480     19401     1.5
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  yr_built      lat  \
# ...

# %%
# Training the model

# %%
X = dff.drop('price', axis=1).values

# %%
y = dff['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
# Creating the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15108, 19)

# %%
model = Sequential()

# %%
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
# Fitting model to train and test data

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=128, epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 3ms/step - loss: 409815220224.0000 - val_loss: 407763156992.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 316036382720.0000 - val_loss: 86700081152.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 84544512000.0000 - val_loss: 81532428288.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 78064164864.0000 - val_loss: 74455228416.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 69679726592.0000 - val_loss: 65642172416.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 59740299264.0000 - val_loss: 55581933568.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 50184523776.0000 - val_loss: 48433111040.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 1ms/step

# %%
predictions
# Out:
# array([[179303.7 ],
#        [438664.03],
#        [277667.6 ],
#        ...,
#        [193045.05],
#        [774492.56],
#        [738508.94]], dtype=float32)

# %%
mean_squared_error(y_test, predictions)
# Out:
# 19035038664.21369

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 80212.5850568445

# %%
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 137967.5275715764

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.8465377715023615

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
single_new_house1 = dff[dff['price'] == 221900].iloc[0].drop('price')

# %%
single_new_house1
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# yr_built         1955.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# basement            0.0000
# renovated           0.0000
# Name: 0, dtype: float64

# %%
single_new_house1.values.reshape(-1, 19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  1.95500e+03,  4.75112e+01,
#         -1.22257e+02,  1.34000e+03,  5.65000e+03,  1.00000e+01,
#          2.01400e+03,  0.00000e+00,  0.00000e+00]])

# %%
single_new_house1 = scaler.transform(single_new_house1.values.reshape(-1,19))

# %%
model.predict(single_new_house1)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[247371.73]], dtype=float32)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_test.shape
# Out:
# (6476,)

# %%
y_pred = predictions.reshape(6476,)
y_pred.shape
# Out:
# (6476,)

# %%
y_test
# Out:
# array([225000., 384200., 334000., ..., 265000., 872500., 720000.])

# %%
y_pred
# Out:
# array([179303.7 , 438664.03, 277667.6 , ..., 193045.05, 774492.56,
#        738508.94], dtype=float32)

# %%
# Conclusion 
# Removing the most expensive 12 houses which seem to increase variance in the data set improves the model.
# This would also mean that this model is incapable of predicting houses that are beyond certain prices. In this case about $3.8M

#Thought
# Since the features are what we use to predict the label (price), when a new data comes in, we are trying to predict the price. Therefore, how do 
# we know that our model is incapable of predicting the price of that house based on its features?
# We only know that the model will not predict accurately beyond certain house prices.
